# %% [markdown]
# # **Linear Regression**
# 👉 Linear Regression is a method used to predict a continuous value using a straight-line relationship between input and output.
#
# 💡 Formula:
# $$y = mx + c$$
# where
# * y = Output
# * x = Input
# * m = Slope/parameter
# * c = Intercept/bias
#
# ## **Loss Function**
# Loss function measures how far an estimated value is from its true value.
# $$Loss = \frac{1}{n}𝚺(\hat{y} - y)^2$$

# %% [markdown]
# # **Multiple Linear Regression**
# A regression technique that predicts a continuous output using two or more input features.
# 💡 Formula:
# $$
# y = w_0 + w_1 x_1 + w_2 x_2 + \cdots + w_n x_n
# $$
#
# Where:
# * y → dependent variable (output)
# * x₁, x₂, …, xₙ → independent variables (features)
# * w₀ → intercept (bias)
# * w₁, w₂, …, wₙ → coefficients (weights)

# %% [markdown]
# # **Model Optimization**
# Optimization refers to determining the **best parameters** for a model such that the **loss function decreases**, resulting in more accurate predictions.

# %% [markdown]
# # **Gradient Descent for Linear Regression :**
# ## **Model :**
# $$y = mx + c $$
# ## **Loss Function :**
# $$J = \frac{1}{n} \sum (\hat{y} - y)^2$$
# ## **Update rule :**
# $$m = m - L \cdot ∂m$$
# $$c = c - L \cdot ∂c$$
# * **m** --> weight
# * **c** --> bias
# * **L** --> Learning Rate is step size taken at each iteration towards minimun
# ## **Partial derivatives :**
# $$\frac{\partial J}{\partial m} = \frac{-2}{n} \sum (\hat{y} - y)\,x$$
#
# $$\frac{\partial J}{\partial c} = \frac{-2}{n} \sum (\hat{y} - y)$$
